# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('./genre_table.csv')
x = df['標籤']
tags = df['全部作品數']
tags25 = df['前25%作品數']
# tags
# sns.histplot(tags, kde=True)
# Out:
# <Axes: xlabel='全部作品數', ylabel='Count'>
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 20840 (\N{CJK UNIFIED IDEOGRAPH-5168}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 21697 (\N{CJK UNIFIED IDEOGRAPH-54C1}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 25976 (\N{CJK UNIFIED IDEOGRAPH-6578}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20840 (\N{CJK UNIFIED IDEOGRAPH-5168}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37096 (\N{CJK UNIFIED IDEOGRAPH-90E8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20316 (\N{CJK UNIFIED IDEOGRAPH-4F5C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21697 (\N{CJK UNIFIED IDEOGRAPH-54C1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\Desktop\期末\趙老師\BaHaMut_ClickThroughRate\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25976 (\N{CJK UNIFIED IDEOGRAPH-6578}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
taglist = df['標籤']


# 常態分布
sns.histplot(agelist, kde=True)
# 中位數和標準差
male_median_value = np.median(male_ages)
male_std_deviation = np.std(male_ages)
female_median_value = np.std(female_ages)
female_std_deviation = np.std(female_ages)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, male_median_value, male_std_deviation)
p2 = norm.pdf(x, female_median_value, female_std_deviation)

plt.plot(x, p, label='male')
plt.plot(x, p2, label='female')
plt.legend()
plt.show()
